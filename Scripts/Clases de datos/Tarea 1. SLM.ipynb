# %% [markdown]
# # Importando librerías y funciones

# %%
import cartopy.crs as ccrs
import cartopy
import matplotlib.pyplot as plt

import cartopy.feature as cfeature
import numpy as np

import netCDF4 as nc
import matplotlib.pyplot as plt
import matplotlib as mp
import pandas as pd
import numpy as np
import scipy as sp
from mpl_toolkits.basemap import Basemap
from datetime import datetime
import os
from os.path import abspath


from mpl_toolkits.axes_grid1 import make_axes_locatable

plt.style.use("seaborn")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bf66f018e6fd> in <module>
#      26         'size'   : 22}
#      27
# ---> 28 matp.rc('font', **font)
#
# NameError: name 'matp' is not defined

# %%
ccrs.PlateCarree()
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (https://matplotlib.org/) -->
# <svg height="153.9pt" version="1.1" viewBox="0 0 293.4 153.9" width="293.4pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 153.9
# L 293.4 153.9
# L 293.4 0
# L 0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 7.2 146.7
# L 7.2 7.2
# L 286.2 7.2
# L 286.2 146.7
# L 7.2 146.7
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="PathCollection_1">
#     <path clip-path="url(#pb7bd19b686)" d="M 19.822506 137.861642
# L 20.293004 137.573088
# L 21.735037 137.694637
# L 22.509189 137.937576
# L 23.101136 138.210912
# L 23.313658 138.560181
# L 21.826109 138.666512
# L 20.809119 138.393136
# L 20.353759 138.1198
# L 20.323382 138.074224
# L 19.822506 137.861642
# " style="fill:none;stroke:#000000;stroke-width:0.3;"/>
#     <path clip-path="url(#pb7bd19b686)" d="M 141.896639 35.202637
# L 142.024436 35.756278
# L 141.438636 36.448409
# L 140.064747 36.906292
# L 138.967759 36.789148
# L 139.596131 35.979913
# L 139.191393 35.191944
# L 140.24581 34.584998
# L 140.83157 34.222993
# L 141.481269 34.191033
# L 142.31199 34.670183
# L 141.896639 35.202637
# " style="fill:none;stroke:#000000;stroke-width:0.3;"/>
#     <path clip-path="url(#pb7bd19b686)" d="M 255.975163 78.965117
# L 257.319816 79.499094
# L 258.752578 79.942599
# L 259.286674 80.339647
# L 259.718084 80.729286
# L 259.835989 81.185847
# L 261.127257 81.664836
# L 261.315608 82.075861
# L 260.602452 82.159284
# L 260.773702 82.675719
# L 261.465593 83.184184
# L 261.968932 84.006114
# L 262.412797 83.980363
# L 262.381639 84.323665
# L 262.980015 84.455347
# L 262.747569 84.601526
# L 263.571261 84.927607
# L 263.485196 85.151603
# L 262.972005 85.205669
# L 262.78129 85.004782
# L 262.115432 84.917715
# L 261.332589 84.801092
# L 260.729968 84.306644
# L 260.290108 83.88048
# L 259.887573 83.202246
# L 258.87673 82.863349
# L 258.220243 83.084381
# L 257.746941 83.340256
# L 257.845783 83.911878
# L 257.237034 84.178286
# L 256.802901 84.048687
# L 256.001235 84.016367
# L 255.311147 83.380305
# L 254.524019 83.224433
# L 254.333144 83.445225
# L 253.351217 83.469054
# L 253.680302 82.838359
# L 254.168182 82.623174
# L 253.966133 81.780458
# L 253.594076 81.129858
# L 252.091669 80.473572
# L 251.452563 80.408772
# L 250.288732 79.692611
# L 250.059971 80.069234
# L 249.762566 80.137558
# L 249.586629 79.853369
# L 249.584186 79.516635
# L 248.992098 79.135927
# L 249.826805 78.856824
# L 250.379524 78.871882
# L 250.314564 78.66627
# L 249.180089 78.664708
# L 248.873072 78.203301
# L 248.180701 78.060205
# L 247.852658 77.676733
# L 248.897342 77.488982
# L 249.29459 77.236392
# L 250.5388 77.554663
# L 250.66111 77.842697
# L 250.877536 79.096118
# L 251.679642 79.559968
# L 252.327319 78.737958
# L 253.216572 78.270223
# L 253.905539 78.269542
# L 254.568314 78.539754
# L 255.14318 78.816975
# L 255.975163 78.965117
# " style="fill:none;stroke:#000000;stroke-width:0.3;"/>
#     <path clip-path="url(#pb7bd19b686)" d="M 235.208113 73.442448
# L 235.51497 73.152491
# L 236.174301 72.728009
# L 236.771074 72.189027
# L 237.161955 71.583302
# L 237.47546 71.580759
# L 237.87363 71.972821
# L 237.909033 72.309695
# L 238.419461 72.525761
# L 239.065976 72.758927
# L 239.010788 73.062501
# L 238.490788 73.100948
# L 238.629199 73.479393
# L 238.058577 73.743398
# L 237.617755 74.443318
# L 238.187456 75.17704
# L 238.053611 75.533578
# L 238.922479 76.25078
# L 238.00419 76.342213
# L 237.745712 76.870582
# L 237.779274 77.572886
# L 237.034038 78.102897
# L 237.013693 78.874726
# L 236.714765 80.059863
# L 236.600665 79.784204
# L 235.720222 80.132913
# L 235.413205 79.65917
# L 234.860646 79.615356
# L 234.474171 79.367051
# L 233.552798 79.645754
# L 233.27005 79.270693
# L 232.762386 79.313305
# L 232.123481 79.223875
# L 232.004975 78.184477
# L 231.61826 77.969053
# L 231.246202 77.306118
# L 231.13831 76.628084
# L 231.228581 75.910001
# L 231.689027 75.394968
# L 232.257005 75.660575
# L 232.855861 75.515757
# L 233.011813 74.85959
# L 233.342619 74.71343
# L 234.271602 74.545644
# L 234.827525 73.93253
# L 235.208113 73.442448
# " style="fill:none;stroke:#000000;stroke-width:0.3;"/>
#     <path clip-path="url(#pb7bd19b686)" d="M 74.150114 18.840502
# L 73.728396 19.140931
# L 72.603273 19.08318
# L 71.663778 18.881092
# L 72.076345 18.532183
# L 73.190615 18.323406
# L 73.867246 18.595221
# L 74.150114 18.840502
# " style="fill:none;stroke:#000000;stroke-width:0.3;"/>
#     <path clip-path="url(#pb7bd19b686)" d="M 73.973998 16.872002
# L 73.620904 16.894209
# L 72.168518 16.844789
# L 71.961864 16.628162
# L 73.522503 16.639496
# L 74.066491 16.783393
# L 73.973998 16.872002
# " style="fill:none;stroke:#000000;stroke-width:0.3;"/>
#     <path clip-path="url(#pb7bd19b686)" d="M 71.715341 15.906495
# L 72.64156 16.175806
# L 72.431521 16.455871
# L 71.284872 16.615787
# L 70.653676 16.435786
# L 70.321527 16.144968
# L 70.260212 15.824254
# L 71.263646 15.855212
# L 71.715341 15.906495
# " style="fill:none;stroke:#000000;stroke-width:0.3;"/>
#     <path clip-path="url(#pb7bd19b686)" d="M 78.383479 19.295962
# L 77.13234 19.200445
# L 75.072608 18.950738
# L 74.804579 18.525215
# L 74.710323 18.140942
# L 73.932286 17.802586
# L 72.329095 17.70793
# L 71.430931 17.467915
# L 71.72253 17.149924
# L 73.319833 17.199144
# L 74.180211 17.448371
# L 75.706107 17.446649
# L 76.375069 17.701562
# L 76.198512 17.99264
# L 77.087766 18.167975
# L 77.580011 18.352122
# L 78.625336 18.386204
# L 79.756126 18.451123
# L 80.98804 18.283117
# L 82.56608 18.217156
# L 83.825389 18.271663
# L 84.655429 18.563942
# L 84.828702 18.884576
# L 84.345228 19.09059
# L 83.189647 19.257094
# L 82.197607 19.162878
# L 79.974474 19.282225
# L 78.383479 19.295962
# " style="fill:none;stroke:#000000;stroke-width:0.3;"/>
#     <path clip-path="url(#pb7bd19b686)" d="M 60.470056 16.381439
# L 61.5628 16.502848
# L 61.305123 16.734813
# L 59.860327 16.957848
# L 58.710934 16.70754
# L 59.338445 16.460436
# L 60.470056 16.381439
# " style="fill:none;stroke:#000000;stroke-width:0.3;"/>
#     <path clip-path="url(#pb7bd19b686)" d="M 60.703163 15.876558
# L 61.711062 16.033471
# L 60.766981 16.184617
# L 59.479879 16.183876
# L 59.492435 16.07332
# L 60.287492 15.841255
# L 60.703163 15.876558
# " style="fill:none;stroke:#000000;stroke-width:0.3;"/>
#     <path clip-path="url(#pb7bd19b686)" d="M 95.331113 62.60106
# L 95.72724 62.669324
# L 95.866972 62.823273
# L 95.668448 63.018673
# L 95.085051 63.014087
# L 94.632274 63.041421
# L 94.587119 62.709773
# L 94.696974 62.596534
# L 95.331113 62.60106
# " style="fill:none;stroke:#000000;stroke-width:0.3;"/>
#     <path clip-path="url(#pb7bd19b686)" d="M 86.583559 62.619843
# L 87.105121 62.689328
# L 87.516847 62.875457
# L 87.645265 63.087678
# L 87.100515 63.102116
# L 86.865085 63.231635
# L 86.431332 63.107262
# L 85.988268 62.824875
# L 86.081262 62.647737
# L 86.407042 62.593731
# L 86.583559 62.619843
# " style="fill:none;stroke:#000000;stroke-width:0.3;"/>
#     <path clip-path="url(#pb7bd19b686)" d="M 82.942183 58.978827
# L 83.611546 59.034115
# L 84.220454 59.042845
# L 84.948369 59.30689
# L 85.256848 59.590619
# L 85.980738 59.503071
# L 86.255196 59.685175
# L 86.911523 60.165165
# L 87.394036 60.514715
# L 87.649169 60.504062
# L 88.111378 60.662116
# L 88.054928 60.880304
# L 88.626231 60.912224
# L 89.212031 61.229393
# L 89.120098 61.410957
# L 88.604764 61.509338
# L 88.083123 61.547825
# L 87.549166 61.48651
# L 86.439502 61.562002
# L 86.959041 61.129651
# L 86.643193 60.928343
# L 86.143599 60.87654
# L 85.875809 60.652825
# L 85.692103 60.211462
# L 85.254125 60.241639
# L 84.531457 60.033824
# L 84.298911 59.871264
# L 83.288769 59.751156
# L 83.018256 59.59999
# L 83.308874 59.406352
# L 82.548679 59.366683
# L 81.991794 59.769399
# L 81.67068 59.780212
# L 81.559583 59.969304
# L 81.176052 60.054049
# L

# %%
plt.axes(projection=ccrs.PlateCarree())

# %%
projections = [ccrs.PlateCarree(),
               ccrs.Robinson(),
               ccrs.Mercator(),
               ccrs.Orthographic(),
               ccrs.InterruptedGoodeHomolosine()
              ]


for proj in projections:
    plt.figure()
    ax = plt.axes(projection=proj)
    ax.stock_img()
    ax.coastlines()
    ax.set_title(f'3')

# %%
# central_lat = 37.5
# central_lon = -96

extent = [lon[0], lon[-1], lat[-1], lat[0]]
central_lon = np.mean(extent[:2])
central_lat = np.mean(extent[2:])

plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.AlbersEqualArea(central_lon, central_lat))
ax.set_extent(extent)

ax.add_feature(cartopy.feature.OCEAN)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.LAKES, edgecolor='black')
ax.add_feature(cartopy.feature.RIVERS)
ax.gridlines()

# %% [markdown]
# La siguiente función ayuda a leer un archivo netcdf

# %%
from sklearn.utils import check_random_state

# %%
def reading_netcdf(ruta):
    data=nc.Dataset(ruta)
    for i in data.variables:
        try:
            print (i,data.variables[i].shape,data.variables[i].units) 
        except:
            print (i,data.variables[i].shape) 
    print("\n")
    return data

# %% [markdown]
# Función para obtener realizar un análisis espectral

# %%
def T_fourier(serie):
    fourier=np.fft.fft(serie)
    freq= np.fft.fftfreq(len(serie)) 
    pot = np.abs(fourier*1/len(serie))**2
    periodos = 1/freq
    freq_pos=np.where(freq>=0)[0]
    
    return fourier,freq_pos,pot,periodos,freq

# %% [markdown]
# # Cargando los datos

# %%
# carpeta = "D:\Google Drive\Documents\Semestre 10\Analisis de datos ambientales\Tarea 1\Dataset"
# rutas = [abspath(element.path) for element in os.scandir(carpeta) if abspath(element.path)[-2:]=="nc"]
# for i in range(0,len(rutas)):
#     data=reading_netcdf(rutas[i])
#     if i==0:
#         ssh=data.variables["ssha"][:,:,:]
#     else:
#         ssh2=data.variables["ssha"][:,:,:]
#         ssh=np.concatenate((ssh,ssh2))
#     lat=data.variables["lat"][:]
#     lon=data.variables["lon"][:]

# %%
ruta= "../Dataset/Glorys/1998.nc"
data=reading_netcdf(ruta)
lon=data["longitude"][:]
lat=data["latitude"][:]
sst=data["sla"][:]
time=data["time"][:]
# Out:
# sla (366, 321, 1440) m
# time (366,) days since 1950-01-01 00:00:00
# latitude (321,) degrees_north
# longitude (1440,) degrees_east

# %%
len(sst[0][0][:])
# Out:
# 1440

# %%
idx_lon=np.where((lon>260)&(lon<270))[0]
idx_lat=np.where((lat>4)&(lat<6))[0]

# %%
np.shape(sst[0][idx_lat][idx_lon])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-203-00b38d8f2e80> in <module>
# ----> 1 np.shape(sst[0][idx_lat][idx_lon])
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/numpy/ma/core.py in __getitem__(self, indx)
#    3170         # mask of being reshaped if it hasn't been set up properly yet
#    3171         # So it's easier to stick to the current version
# -> 3172         dout = self.data[indx]
#    3173         _mask = self._mask
#    3174
#
# IndexError: index 1040 is out of bounds for axis 0 with size 8

# %%
# sst=sst[50,:,:,np.newaxis]
# np.shape(sst[50,176:183,1040:1079])
# Out:
# (7, 39)

# %%
# plt.figure(figsize=(8,100))
ax = plt.axes(projection=ccrs.PlateCarree())
x,y=np.meshgrid(lon[idx_lon],lat[idx_lat])
cf=ax.contourf(x,y,sst[0,idx_lat[0]:idx_lat[-1]+1,idx_lon[0]:idx_lon[-1]+1],50,transform=ccrs.PlateCarree(),cmap="bwr")
ax.coastlines()
plt.colorbar(cf,fraction=0.01, pad=0.04)
plt.show()

# %%
figure=plt.figure(figsize=(16,10))
ax = plt.axes(projection=ccrs.PlateCarree())
cf=ax.contourf(lon, lat, sst[20,:,idx_lon],50,transform=ccrs.PlateCarree(),cmap="bwr")
ax.coastlines()
plt.colorbar(cf,fraction=0.01, pad=0.04)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-8553fc5f1cc7> in <module>
#       1 figure=plt.figure(figsize=(16,10))
#       2 ax = plt.axes(projection=ccrs.PlateCarree())
# ----> 3 cf=ax.contourf(lon, lat, sst[20,:,idx_lon],50,transform=ccrs.PlateCarree(),cmap="bwr")
#       4 ax.coastlines()
#       5 plt.colorbar(cf,fraction=0.01, pad=0.04)
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py in contourf(self, *args, **kwargs)
#    1398                         sub_trans.force_path_ccw = True
#    1399
# -> 1400         result = matplotlib.axes.Axes.contourf(self, *args, **kwargs)
#    1401
#    1402         # We need to compute the dataLim correctly for contours.
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6420     def contourf(self, *args, **kwargs):
#    6421         kwargs['filled'] = True
# -> 6422         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6423         self.autoscale_view()
#    6424         return contours
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     853         self._transform = kwargs.pop('transform', None)
#     854
# --> 855         kwargs = self._process_args(*args, **kwargs)
#     856         self._process_levels()
#     857
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/matplotlib/contour.py in _process_args(self, *args, **kwargs)
#    1454                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1455
# -> 1456             x, y, z = self._contour_args(args, kwargs)
#    1457
#    1458             _mask = ma.getmask(z)
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1512             args = args[1:]
#    1513         elif Nargs <= 4:
# -> 1514             x, y, z = self._check_xyz(args[:3], kwargs)
#    1515             args = args[3:]
#    1516         else:
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1547
#    1548         if z.ndim != 2:
# -> 1549             raise TypeError("Input z must be a 2D array.")
#    1550         elif z.shape[0] < 2 or z.shape[1] < 2:
#    1551             raise TypeError("Input z must be at least a 2x2 array.")
#
# TypeError: Input z must be a 2D array.

# %% [markdown]
# # Definiendo la serie temporal

# %% [markdown]
# A continuación se preparan las series de datos espacio-temporales a usar y se determina la serie temporal final que será evaluada a través de el análisis espectral

# %%
lat_max = 7.5
lat_min = 0.5
lon_max = 283.5
lon_min = 276.5

ind_lat = np.where((lat<=lat_max) & (lat>=lat_min))[0]
ind_lon = np.where((lon<=lon_max) & (lon>=lon_min))[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-2692ea9902ef> in <module>
#       4 lon_min = 276.5
#       5
# ----> 6 ind_lat = np.where((lat<=lat_max) & (lat>=lat_min))[0]
#       7 ind_lon = np.where((lon<=lon_max) & (lon>=lon_min))[0]
#
# NameError: name 'lat' is not defined

# %%
x,y=np.meshgrid(lon[ind_lon],lat[ind_lat])
plt.figure()
plt.contourf(x,y,sst[0,ind_lat[0]:ind_lat[-1]+1,ind_lon[0]:ind_lon[-1]+1],cmap="plasma")
plt.colorbar(orientation="horizontal")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-298792ca9259> in <module>
# ----> 1 x,y=np.meshgrid(lon[ind_lon],lat[ind_lat])
#       2 plt.figure()
#       3 plt.contourf(x,y,sst[0,ind_lat[0]:ind_lat[-1]+1,ind_lon[0]:ind_lon[-1]+1],cmap="plasma")
#       4 plt.colorbar(orientation="horizontal")
#
# NameError: name 'lon' is not defined

# %% [markdown]
# La serie temporal que se determinará para la región del océano pacífico colombiano será el promedio longitudinal y latitudinal de los datos obtenidos

# %%
sst_lat=np.mean(sst[:,ind_lat,:],axis=1)
sst_mean=np.mean(sst_lat[:,ind_lon],axis=1)

sst_mean_anm=sst_mean-np.mean(sst_mean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-869556fec9e9> in <module>
# ----> 1 sst_lat=np.mean(sst[:,ind_lat,:],axis=1)
#       2 sst_mean=np.mean(sst_lat[:,ind_lon],axis=1)
#       3
#       4 sst_mean_anm=sst_mean-np.mean(sst_mean)
#
# NameError: name 'sst' is not defined

# %% [markdown]
# ## Graficando la serie

# %%
# %matplotlib qt
plt.figure()
plt.suptitle("Serie de datos promediados espacialmente")
plt.subplot(121)
plt.plot(sst_mean,c="darkcyan")
plt.ylabel("slm [m]")

plt.subplot(122)
plt.plot(sst_mean_anm,c="navy")
plt.ylabel("slm [m]")
# plt.savefig(".\Graficas\Series.jpg",dpi=800,box_inches="tight",pad_inches=0)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-bf5a8200bb4a> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'qt')
#       2 plt.figure()
#       3 plt.suptitle("Serie de datos promediados espacialmente")
#       4 plt.subplot(121)
#       5 plt.plot(sst_mean,c="darkcyan")
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2312                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2313             with self.builtin_trap:
# -> 2314                 result = fn(*args, **kwargs)
#    2315             return result
#    2316
#
# </home/franklin/my_projects_dir/entorno_jup/lib/python3.6/site-packages/decorator.py:decorator-gen-108> in matplotlib(self, line)
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    3412                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    3413
# -> 3414         pt.activate_matplotlib(backend)
#    3415         pt.configure_inline_support(self, backend)
#    3416
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/IPython/core/pylabtools.py in activate_matplotlib(backend)
#     312
#     313     import matplotlib.pyplot
# --> 314     matplotlib.pyplot.switch_backend(backend)
#     315
#     316     # This must be imported last in the matplotlib series, after
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/matplotlib/pyplot.py in switch_backend(newbackend)
#     219         else "matplotlib.backends.backend_{}".format(newbackend.lower()))
#     220
# --> 221     backend_mod = importlib.import_module(backend_name)
#     222     Backend = type(
#     223         "Backend", (matplotlib.backends._Backend,), vars(backend_mod))
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/matplotlib/backends/backend_qt5agg.py in <module>
#       9 from .. import cbook
#      10 from .backend_agg import FigureCanvasAgg
# ---> 11 from .backend_qt5 import (
#      12     QtCore, QtGui, QtWidgets, _BackendQT5, FigureCanvasQT, FigureManagerQT,
#      13     NavigationToolbar2QT, backend_version)
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/matplotlib/backends/backend_qt5.py in <module>
#      13     _Backend, FigureCanvasBase, FigureManagerBase, NavigationToolbar2,
#      14     TimerBase, cursors, ToolContainerBase, StatusbarBase, MouseButton)
# ---> 15 import matplotlib.backends.qt_editor.figureoptions as figureoptions
#      16 from matplotlib.backends.qt_editor.formsubplottool import UiSubplotTool
#      17 from matplotlib.backend_managers import ToolManager
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/matplotlib/backends/qt_editor/figureoptions.py in <module>
#      11 import matplotlib
#      12 from matplotlib import cm, colors as mcolors, markers, image as mimage
# ---> 13 from matplotlib.backends.qt_compat import QtGui
#      14 from matplotlib.backends.qt_editor import _formlayout
#      15
#
# ~/my_projects_dir/entorno_jup/lib/python3.6/site-packages/matplotlib/backends/qt_compat.py in <module>
#     156         break
#     157     else:
# --> 158         raise ImportError("Failed to import any qt binding")
#     159 else:  # We should not get there.
#     160     raise AssertionError("Unexpected QT_API: {}".format(QT_API))
#
# ImportError: Failed to import any qt binding

# %% [markdown]
# # Realizando el análisis espectral

# %%
sst_fourier,sst_freq_pos,sst_potencias,sst_periodos,sst_freq,=T_fourier(sst_mean_anm)

# %% [markdown]
# ## Graficando el espectro de potencias

# %%
plt.figure()
plt.plot(sst_periodos[sst_freq_pos],sst_potencias[sst_freq_pos],'-o',c="firebrick")
# plt.xscale("log")
plt.xlabel("Período [meses]")
plt.ylabel("Potencia")
plt.savefig(".\Graficas\Espectro de potencias.jpg",dpi=800,box_inches="tight",pad_inches=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-d759a96ea131> in <module>
#       1 plt.figure()
# ----> 2 plt.plot(sst_periodos[sst_freq_pos],sst_potencias[sst_freq_pos],'-o',c="firebrick")
#       3 # plt.xscale("log")
#       4 plt.xlabel("Período [meses]")
#       5 plt.ylabel("Potencia")
#
# NameError: name 'sst_periodos' is not defined

# %% [markdown]
# ## Seleccionando la banda de interés

# %% [markdown]
# Puede notarse que el intervalo de períodos que más regula la variable de nivel medio del mar está comprendido entre ... y ... días.

# %%
freq_fil=np.copy(sst_fourier)
freq_fil[np.where(np.abs(1/sst_freq)>5)]=0

Pot_fil=np.abs(freq_fil*1/len(freq_fil))**2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-b08271d3ff1a> in <module>
# ----> 1 freq_fil=np.copy(sst_fourier)
#       2 freq_fil[np.where(np.abs(1/sst_freq)>5)]=0
#       3
#       4 Pot_fil=np.abs(freq_fil*1/len(freq_fil))**2
#
# NameError: name 'sst_fourier' is not defined

# %%
plt.figure()
plt.title("Banda espectral de interés")
plt.plot(sst_periodos[sst_freq_pos],Pot_fil[sst_freq_pos],'-o')
# plt.xscale("log")
plt.xlabel("Período [meses]")
plt.ylabel("Potencia")
plt.axvline(2,0,1,ls='--',c="k")
plt.axvline(5,0,1,ls='--',c="k")
plt.xlim(0,24)
plt.savefig(".\Graficas\Banda espectral interes.jpg",dpi=800,box_inches="tight",pad_inches=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-07e59838ae85> in <module>
#       1 plt.figure()
#       2 plt.title("Banda espectral de interés")
# ----> 3 plt.plot(sst_periodos[sst_freq_pos],Pot_fil[sst_freq_pos],'-o')
#       4 # plt.xscale("log")
#       5 plt.xlabel("Período [meses]")
#
# NameError: name 'sst_periodos' is not defined

# %% [markdown]
# # Mapa de varianza

# %%
var_banda.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-a31646dc4316> in <module>
# ----> 1 var_banda.shape
#
# NameError: name 'var_banda' is not defined

# %%
sst_var=sum(Pot_fil)
# pearson=np.zeros((len(lat)),len(lon))
# pearson_banda=np.zeros()
var=np.zeros((len(lat),len(lon)))
var_banda=np.zeros((len(lat),len(lon)))
var_porcentaje=np.zeros((len(lat),len(lon)))
# matriz_inversa=np.zeros((len(time)),len(lat),len(lon))

for i in range(len(lat)):
    for j in range(len(lon)):
#         sst_array=np.array(sst)
        point=sst[:,i,j]
        point_anm=point-np.mean(point)
        tf_p,fp_p,pot_p,per_p,f_p=T_fourier(point_anm)
        pos_banda=np.where((np.abs(per_p)>18) & (np.abs(per_p)<96))[0]
#         print(len(pos_banda))
        var_banda[i,j]=sum(pot_p[pos_banda])
        var[i,j]=np.var(point)
        var_porcentaje[i,j]=(sum(pot_p[pos_banda])/np.var(point))*100
        
#         pearson[i,j]=pearsonr(serie,slm[:,i,j])[0]
#         spearman[i,j]=spearmanr(serie,slm[:,i,j])[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-b8421eac002b> in <module>
# ----> 1 sst_var=sum(Pot_fil)
#       2 # pearson=np.zeros((len(lat)),len(lon))
#       3 # pearson_banda=np.zeros()
#       4 var=np.zeros((len(lat),len(lon)))
#       5 var_banda=np.zeros((len(lat),len(lon)))
#
# NameError: name 'Pot_fil' is not defined

# %%
vb=var_banda[ind_lat[0]:ind_lat[-1]+1,ind_lon[0]:ind_lon[-1]+1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-d41b77c3ada0> in <module>
# ----> 1 vb=var_banda[ind_lat[0]:ind_lat[-1]+1,ind_lon[0]:ind_lon[-1]+1]
#
# NameError: name 'var_banda' is not defined

# %%
fig=plt.figure(figsize=(20,16))
ax=fig.add_subplot(111)

N,S,W,E=90,-90,260,0

m=Basemap(llcrnrlat=lat[-1],urcrnrlat=lat[0],
            llcrnrlon=lon[0],urcrnrlon=lon[-1],resolution='l',area_thresh=10000)
x,y=m(*np.meshgrid(lon,lat))
cs=m.contourf(x,y,var_porcentaje,levels=np.arange(0,0.65,0.05),cmap="seismic")
cbar = m.colorbar(location='bottom',pad='10%')
m.drawparallels(np.arange(-90,90,10),labels=[1,0,0,0],size=11,linewidth=0.1)
m.drawmeridians(np.arange(0,360,20),labels=[0,1,0,1],size=11, linewidth=0.1)
m.drawcoastlines()
# m.drawmapboundary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-b4f77f1363d4> in <module>
#       4 N,S,W,E=90,-90,260,0
#       5
# ----> 6 m=Basemap(llcrnrlat=lat[-1],urcrnrlat=lat[0],
#       7             llcrnrlon=lon[0],urcrnrlon=lon[-1],resolution='l',area_thresh=10000)
#       8 x,y=m(*np.meshgrid(lon,lat))
#
# NameError: name 'lat' is not defined

# %%
# lat_max = 7.5
# lat_min = 0.5
# lon_max = 283.5
# lon_min = 276.5

# fig=plt.figure(figsize=(20,16))
# ax=fig.add_subplot(111)

# N,S,W,E=8,0,285,275

# m=Basemap(E,S,W,N,resolution='l',area_thresh=10000)
# x,y=m(*np.meshgrid(lon[ind_lon],lat[ind_lat]))
# cs=m.contourf(x,y,vb,cmap="seismic")
# cbar = m.colorbar(location='bottom',pad='10%')
# m.drawparallels(np.arange(0,8,2),labels=[1,0,0,0],size=11,linewidth=0.1)
# m.drawmeridians(np.arange(0,360,20),labels=[0,1,0,1],size=11, linewidth=0.1)
# m.drawcoastlines()
# m.drawmapboundary()

# %%
w=1/(3*12)
np.exp(-2j*np.pi()*w*np.arange(len(rolling_)))

# %%
serie.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-db9464374852> in <module>
# ----> 1 serie.values
#
# NameError: name 'serie' is not defined
